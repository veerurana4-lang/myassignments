# %% [markdown]
# 1. Who developed Python Programming Language?
# Ans. Python was developed by Guido van Rossum

# %% [markdown]
# 2. Which type of Programming does Python support?
# Ans. Python supports:
#
# Object-Oriented Programming (OOP)
#
# Procedural Programming
#
# Functional Programming

# %% [markdown]
# 3. Is Python case sensitive when dealing with identifiers?
# Ans. Yes, Python is case-sensitive.

# %% [markdown]
# 4. What is the correct extension of the Python file?
# Ans. correct extension is .py

# %% [markdown]
# 5. Is Python code compiled or interpreted?
# Ans.
# Python is interpreted language.
# But internally, it first compiles code into bytecode and then executes it using the Python Virtual Machine (PVM).

# %% [markdown]
# 6. Name a few blocks of code used to define in Python language?
# Ans.
# Blocks of code in Python include:
#
# if
# else
# elif
# for
# while
# def (function)
# class

# %% [markdown]
# 7. State a character used to give single-line comments in Python?
# Ans. #

# %%
#8. Mention functions which can help us to find the version of python that we are currently working on?
#Ans. 
import sys
print(sys.version)

# %% [markdown]
# 9. Python supports the creation of anonymous functions at runtime, using a construct called
# Ans. lambda

# %% [markdown]
# 10. What does pip stand for in Python?
# Ans. Pip Installs Packages

# %% [markdown]
# 11. Mention a few built-in functions in Python?
# Ans. Some built-in functions:
# print()
# len()
# type()
# input()
# sum()
# max()
# min()
# range()
# abs()

# %% [markdown]
# 12. What is the maximum possible length of an identifier in Python?
# Ans. There is no fixed limit.

# %% [markdown]
# 13. What are the benefits of using Python?
# Ans. Easy to learn and read
# Large standard library
# Platform independent
# Supports OOP
# Used in AI, ML, Data Science, Web Development
# Huge community support

# %% [markdown]
# 14. How is memory managed in Python?
# Ans. Memory is managed automatically.
# Python uses Garbage Collection.

# %% [markdown]
# 15. How to install Python on Windows and set path variables?
# Steps:
# Go to python.org
# Download Python for Windows
# Run installer
# Tick “Add Python to PATH”
# Click Install

# %% [markdown]
# 16. Is indentation required in Python?
# Ans. Yes
# Indentation is mandatory in Python.
# It defines blocks of code.
# Without indentation it gives error.
